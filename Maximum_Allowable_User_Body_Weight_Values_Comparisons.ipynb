# %% [markdown]
# <a href="https://colab.research.google.com/github/RebeccaKinnie/Research-and-Design-Project-2023/blob/main/Maximum_Allowable_User_Body_Weight_Values_Comparisons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Box Plot showing the Values for the *'Maximum Allowable User Body Weight (kg)'* for the first defined stiffness category for each of the manufacturer companies. This is one of the variables that allows for the comparison of stiffness categories. The boxplot will show the distrubtuion of data values, allowing the standard error to be calculated.

# %%
import matplotlib.pyplot as plt
import numpy as np


# data set values of the 'Maximum Allowable User Body Weight (kg)'
data1 = [59, 74.8, 77.1, 66.2, 81.2]

# calculate the Mean and Standard Deviation
mean_value1 = np.mean(data1)
std_deviation1 = np.std(data1)

# display the mean value and the standard deviation
plt.text(1, mean_value1, f'Mean: {mean_value1:.2f}', verticalalignment='bottom', horizontalalignment='right', color='green')
plt.text(1, std_deviation1, f'Standard Deviation: {std_deviation1:.2f}', verticalalignment='bottom', horizontalalignment='right', color='blue')

# create a boxplot
plt.boxplot(data1)

# add labels and a title to the boxplot
plt.xlabel('Stiffness Category 1, Data Set 1')
plt.ylabel('Specified Weight (kg)')
plt.title('Maximum Allowable User Body Weight (kg) values for each first provided stiffness category')

plt.show()

# %% [markdown]
# Box Plot showing the Values for the *'Maximum Allowable User Body Weight (kg)'* for the second defined stiffness category for each of the manufacturer companies. This is one of the variables that allows for the comparison of stiffness categories. The boxplot will show the distrubtuion of data values, allowing the standard error to be calculated.

# %%
import matplotlib.pyplot as plt
import numpy as np


# data set values of the 'Maximum Allowable User Body Weight (kg)'
data2 = [81.6, 86.2, 87.99, 81.6, 101.6]

# calculate the Mean and Standard Deviation
mean_value2 = np.mean(data2)
std_deviation2 = np.std(data2)

# display the mean value and the standard deviation
plt.text(1, mean_value2, f'Mean: {mean_value2:.2f}', verticalalignment='bottom', horizontalalignment='right', color='green')
plt.text(1, std_deviation2, f'Standard Deviation: {std_deviation2:.2f}', verticalalignment='bottom', horizontalalignment='right', color='blue')

# create a boxplot
plt.boxplot(data2)

# add labels and a title to the boxplot
plt.xlabel('Stiffness Category 2, Data Set 2')
plt.ylabel('Specified Weight (kg)')
plt.title('Maximum Allowable User Body Weight (kg) values for each second provided stiffness category')

plt.show()

# %% [markdown]
# Box Plot showing the Values for the *'Maximum Allowable User Body Weight (kg)'* for the third defined stiffness category for each of the manufacturer companies. This is one of the variables that allows for the comparison of stiffness categories. The boxplot will show the distrubtuion of data values, allowing the standard error to be calculated.

# %%
import matplotlib.pyplot as plt
import numpy as np


# data set values of the 'Maximum Allowable User Body Weight (kg)'
data3 = [108.9, 115.7, 100.2, 98.9, 124.7]

# calculate the Mean and Standard Deviation
mean_value3 = np.mean(data3)
std_deviation3 = np.std(data3)

# display the mean value and the standard deviation
plt.text(1, mean_value3, f'Mean: {mean_value3:.2f}', verticalalignment='bottom', horizontalalignment='right', color='green')
plt.text(1, std_deviation3, f'Standard Deviation: {std_deviation3:.2f}', verticalalignment='bottom', horizontalalignment='right', color='blue')

# create a boxplot
plt.boxplot(data3)

# add labels and a title to the boxplot
plt.xlabel('Stiffness Category 3, Data Set 3')
plt.ylabel('Specified Weight (kg)')
plt.title('Maximum Allowable User Body Weight (kg) values for each fourth provided stiffness category')

plt.show()

# %% [markdown]
# Box Plot showing the Values for the *'Maximum Allowable User Body Weight (kg)'* for the fourth defined stiffness category for each of the manufacturer companies. This is one of the variables that allows for the comparison of stiffness categories. The boxplot will show the distrubtuion of data values, allowing the standard error to be calculated.

# %%
import matplotlib.pyplot as plt
import numpy as np


# data set values of the 'Maximum Allowable User Body Weight (kg)'
data4 = [136.1, 116.1, 118.4]

# calculate the Mean and Standard Deviation
mean_value4 = np.mean(data4)
std_deviation4 = np.std(data4)

# display the mean value and the standard deviation
plt.text(1, mean_value4, f'Mean: {mean_value4:.2f}', verticalalignment='bottom', horizontalalignment='right', color='green')
plt.text(1, std_deviation4, f'Standard Deviation: {std_deviation4:.2f}', verticalalignment='bottom', horizontalalignment='right', color='blue')

# create a boxplot
plt.boxplot(data4)

# add labels and a title to the boxplot
plt.xlabel('Stiffness Category 4, Data Set 4')
plt.ylabel('Specified Weight (kg)')
plt.title('Maximum Allowable User Body Weight (kg) values for each third provided stiffness category')

plt.show()
